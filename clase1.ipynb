# %%
import pandas

link="https://github.com/InvestigacionEscuelaGobPUCP/training/raw/master/idhPeru2012.csv"
data=pandas.read_csv(link, encoding='latin1')

# %%
data.head()
# Out:
#     UbiReg   UbiPro       Reg          Pro   UbiDis           Dis     idh  \
# 0  10000.0  10100.0  AMAZONAS  Chachapoyas  10101.0  Chachapoyas   0.5467
# 1  10000.0  10100.0  AMAZONAS  Chachapoyas  10102.0  Asuncion      0.1683
# 2  10000.0  10100.0  AMAZONAS  Chachapoyas  10103.0     Balsas     0.2634
# 3  10000.0  10100.0  AMAZONAS  Chachapoyas  10104.0       Cheto    0.3274
# 4  10000.0  10100.0  AMAZONAS  Chachapoyas  10105.0    Chiliquin   0.2115
#
#    vidaEsp  EducSec  EducAnhos  IngresoFam
# 0    73.39    62.72       9.97       866.6
# 1    73.28     0.75       6.08       342.0
# 2    71.97    14.48       5.28       340.3
# 3    77.84    44.61       4.96       346.8
# 4    76.25     8.03       4.44       258.6
